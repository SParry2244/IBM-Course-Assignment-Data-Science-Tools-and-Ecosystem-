# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ### **Objectives:**
# - Learn to use and create a Jupyter Notebook.
# - List the most popular Programming Languages used by Data Scientists.
# - List the main Libraries used by Data Scientists.
# - Show examples of how a code cell could be used in a Jupyter Notebook environment.

# %% [markdown]
# ### Languages of Data Science
# #### Some popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ### Libraries of Data Science
# #### Some of the commonly used libraries used by Data Scientists include:
# ##### Scientific Computing Libraries in Python:
# 1. Pandas
# 2. Numpy
# 3. Scipy
# 4. Matplotlib
#
# ##### Machine Learning and Deep Learning Libraries in Python:
# 1. Scikit learn
# 2. Keras
# 3. TensorFlow
# 4. Pytorch
# 5. ApacheSpark

# %% [markdown]
# ### Tools of Data Science
# | Data Science Tools |
# | ------------------ |
# | Jupyter |
# | RStudio |
# | Spyder |

# %% [markdown]
# ### Arithmetic expressions in Python
# #### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple arithmetic expression to multiply then add integers.
# When running this cell, the result should be: 17
(3*4)+5

# %%
# This is a simple expresion to convert x minutes into hours by dividing by 60.
# The value of the variable x says how many minutes should be turned into hours.
# When running this cell, the result should be: 3.333...
x = 200
x/60

# %% [markdown]
# ## Author:
# Santiago Parry Mix
